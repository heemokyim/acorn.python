# %%
import pandas as pd
import sklearn
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('분석용(최종).csv', engine='python')
df.shape
df.head()
df.loc[:,"종가":]=df.loc[:,"종가":].apply(pd.to_numeric, errors='coerce')

#df.loc[:,"종가":]=scale(df.loc[:,"종가":])


scaler = MinMaxScaler(feature_range=(-1,1))
signal_data = scaler.fit_transform(df.loc[:,"종가":])
df.loc[:,"종가":]=signal_data
df.loc[:,"종가":]
# Out:
#             종가  삼성전자_거래량     코스피지수     실세총예금  실세_요구불_나누기  실세_저축성_나누기     CD순발행      민간신용   민간신용_대출    외국인_매수      ...       일본_금리  중국_금리     유로_금리  주요상품선물_WTI_  주요상품선물_BRENT_  주요상품선물_DUBAI_  주요상품선물_천연가스_  주요상품선물_금_.1  주요상품선물_은_  주요상품선물_알루미늄_
# 0    -0.648055 -0.988630  0.101869 -0.996613   -0.858803   -1.000000  0.547934 -0.980102 -0.983833 -0.739133      ...         1.0    1.0  0.882353     0.232953       0.178571       0.127683      0.214076    -0.740369  -0.679316      0.095737
# 1    -0.646632 -0.987812  0.101869 -0.995808   -0.876677   -0.995362  0.564560 -0.980102 -0.983833 -0.800652      ...         1.0    1.0  0.882353     0.225563       0.174528       0.174175      0.178886    -0.725126  -0.668761      0.151766
# 2    -0.651611 -0.988661  0.115130 -0.990161   -0.880908   -0.987775  0.567751 -0.980102 -0.983833 -0.648378      ...         1.0    1.0  0.882353     0.204232       0.160883       0.178587      0.212121    -0.730821  -0.670269      0.178563
# ...

# %%
"""import re
#df.종가=df.종가.str.strip(

#a = DataFrame(df.종가)
#a = '539,000'
#a
#re.sub('\D', '', a)
   
        
a = df.종가
a1 = []
for a0 in a:
    a1.append(re.sub('\D', '', a0))

df['종가'] = a1"""
# Out:
# "import re\n#df.종가=df.종가.str.strip(\n\n#a = DataFrame(df.종가)\n#a = '539,000'\n#a\n#re.sub('\\D', '', a)\n   \n        \na = df.종가\na1 = []\nfor a0 in a:\n    a1.append(re.sub('\\D', '', a0))\n\ndf['종가'] = a1"

# %%
"""def delete(a):
    a1=[]
    for a0 in a:
        a1.append(re.sub('\D', '', str(a0)))
    return a1

delete(df.종가)

#print(df)
#df1=df.loc[:,"종가":]
df.apply(delete,axis=1)
"""
# Out:
# 'def delete(a):\n    a1=[]\n    for a0 in a:\n        a1.append(re.sub(\'\\D\', \'\', str(a0)))\n    return a1\n\ndelete(df.종가)\n\n#print(df)\n#df1=df.loc[:,"종가":]\ndf.apply(delete,axis=1)\n'

# %%
y = df.종가

# %%
X = df.loc[:,"삼성전자_거래량":]

# %% [markdown]
# ## RFE를 통한 feature selection

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFECV
from sklearn.svm import SVR
# Out:
# array([17.2134918 , 19.37965436, 14.75030901, 11.81662128,  9.45520588,
#        13.90806032,  3.40447398, 24.20228984, 17.5783377 , 17.51556532,
#        17.40999895, 17.11893656, 21.81510702, 15.88623898, 21.63246599,
#        13.01689624, 22.908266  ,  6.84202611, 10.32969753, 17.70617001,
#         8.52251585,  9.51592807, 19.81663198,  2.99416378,  8.04688453,
#        22.09060713, 18.07976383, 15.64717616,  9.18985112,  8.10886643,
#        11.46237964, 11.27510587,  9.39472899, 19.12963765,  6.75303583,
#         8.59450992, 14.08547252, 15.47556192, 23.37684908, 10.65602456,
#        26.21981092,  7.56662861,  6.09081028, 15.3507226 , 13.30251573,
#        15.05111884, 12.18062778, 23.69853054,  7.89988206, 14.86941989])

# %%
estimator = SVR(kernel="linear")
selector = RFECV(estimator, step=1, cv=5)
selector = selector.fit(X, y)
selector.support_ 

selector.ranking_
# Out:
# array([ 1,  5, 75, 21, 98,  6, 23, 24, 73, 87, 91, 97, 82, 59, 86, 94, 78,
#        45, 90, 68, 44, 74, 61, 29, 60, 76, 83, 96, 64, 92, 72, 77, 11, 71,
#        32, 49, 47, 95, 37, 58,  9,  3, 46,  4,  7, 80, 41, 19, 43, 14, 30,
#        18, 40, 26, 65, 15, 84,  2, 33, 85,  8, 28, 89, 34, 22, 25, 38, 50,
#        48, 67, 66, 36, 62, 55, 10, 31, 16,  1, 69, 54, 17, 57, 79, 88, 20,
#        27, 81, 35, 42, 51, 39, 56, 53, 63, 52, 70, 13, 12, 93])

# %%
"""X.iloc[:,[ 1,  5, 75, 21, 98,  6, 23, 24, 73, 87, 91, 97, 82, 59, 86, 94, 78,
       45, 90, 68, 44, 74, 61, 29, 60, 76, 83, 96, 64, 92, 72, 77, 11, 71,
       32, 49, 47, 95, 37, 58,  9,  3, 46,  4,  7, 80, 41, 19, 43, 14, 30,
       18, 40, 26, 65, 15, 84,  2, 33, 85,  8, 28, 89, 34, 22, 25, 38, 50,
       48, 67, 66, 36, 62, 55, 10, 31, 16,  1, 69, 54, 17, 57, 79, 88, 20,
       27, 81, 35, 42, 51, 39, 56, 53, 63, 52, 70, 13, 12, 93]]"""
# Out:
# 'X.iloc[:,[ 1,  5, 75, 21, 98,  6, 23, 24, 73, 87, 91, 97, 82, 59, 86, 94, 78,\n       45, 90, 68, 44, 74, 61, 29, 60, 76, 83, 96, 64, 92, 72, 77, 11, 71,\n       32, 49, 47, 95, 37, 58,  9,  3, 46,  4,  7, 80, 41, 19, 43, 14, 30,\n       18, 40, 26, 65, 15, 84,  2, 33, 85,  8, 28, 89, 34, 22, 25, 38, 50,\n       48, 67, 66, 36, 62, 55, 10, 31, 16,  1, 69, 54, 17, 57, 79, 88, 20,\n       27, 81, 35, 42, 51, 39, 56, 53, 63, 52, 70, 13, 12, 93]]'

# %%
feature selection
https://machinelearningmastery.com/feature-selection-machine-learning-python/
http://gentlej90.tistory.com/86
https://brunch.co.kr/@itschloe1/11
http://www.science.smith.edu/~jcrouser/SDS293/labs/2016/lab10/Lab%2010%20-%20Ridge%20Regression%20and%20the%20Lasso%20in%20Python.pdf
https://brunch.co.kr/@snobberys/137
